# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import PlayerGameLog
from nba_api.stats.library.parameters import SeasonAll
import csv
import matplotlib.pyplot as plt

import pandas as pd

#saved the result dataframe onto my computer since the file was too big and would time out or take hours to load. 
NBA_df = pd.read_csv("result.csv")

#created a players dataframe of all players, active and inactive
player_dictionary = players.get_players()

# %%
NBA_df.head(1)
# Out:
#    SEASON_ID  Player_ID   Game_ID     GAME_DATE    MATCHUP WL  MIN  FGM  FGA  \
# 0      22019     203500  21900949  MAR 08, 2020  OKC @ BOS  W   26    1    2
#
#    FG_PCT  ...  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE  \
# 0     0.5  ...  6.0    1    3    1    1   1    6           4                1
#
#       full_name
# 0  Steven Adams
#
# [1 rows x 28 columns]

# %%
team_dict = teams.get_teams()
player_dictionary
# Out:
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
#  {'id': 76006,
# ...

# %%
# with open('player_dict.csv', 'w', newline = '') as player_dict:
#     writer = csv.writer(player_dict)
    
#     writer.writerow(['id'])

# player_dict = pd.DataFrame(player_dict, columns= (str['id']))
# player_dict.to_csv('player_dict.csv', index=False)

# %%
player_dictionary
# Out:
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
#  {'id': 76006,
# ...

# %%
# vince = [player for player in player_dictionary if player['full_name'] == 'Vince Carter'][0]

# vince_id = vince['id']

# vince_id

# %%
veterans = []
for i in player_dictionary:
    if i['is_active'] == True:
        veterans.append(i['id'])

# %%
import time
headers = {
    'Host': 'stats.nba.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:61.0) Gecko/20100101 Firefox/61.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://github.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'x-nba-stats-origin': 'stats'
}

# %%
# result = pd.DataFrame()
# for i in veterans:
#     game_history = playergamelog.PlayerGameLog(player_id = i, season = SeasonAll.all, headers=headers)
#     veterans_game_history = game_history.get_data_frames()[0]
#     result = pd.concat([result,veterans_game_history])
#     time.sleep(5)

# %%
len(result.Player_ID.unique())
# Out:
# 514

# %%
result
# Out:
#         SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  \
# 0           22019     203500  21900949  MAR 08, 2020    OKC @ BOS  W   26
# 1           22019     203500  21900932  MAR 06, 2020    OKC @ NYK  W   24
# 2           22019     203500  21900918  MAR 04, 2020    OKC @ DET  W   32
# 3           22019     203500  21900912  MAR 03, 2020  OKC vs. LAC  L   27
# 4           22019     203500  21900882  FEB 28, 2020    OKC @ MIL  L   17
# ...           ...        ...       ...           ...          ... ..  ...
# 148648      22016    1627826  21600367  DEC 12, 2016    LAL @ SAC  L    2
# 148649      22016    1627826  21600326  DEC 07, 2016    LAL @ HOU  L    5
# 148650      22016    1627826  21600142  NOV 13, 2016    LAL @ MIN  L    8
# 148651      22016    1627826  21600078  NOV 04, 2016  LAL vs. GSW  W    1
# 148652      22016    1627826  21600059  NOV 02, 2016    LAL @ ATL  W   19
#
#         FGM  FGA  FG_PCT  ...   REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# ...

# %%
veterans_dictionary = {}
for i in player_dictionary:
    veterans_dictionary[i['id']] = i['full_name']

# %%
#added the full_name to the result dataframe to showcase the players name as opposed to the player_id which is just
#a bunch of numbers

NBA_df['full_name'] = NBA_df['Player_ID'].map(veterans_dictionary)

# %%
NBA_df['full_name']
# Out:
# 0         Steven Adams
# 1         Steven Adams
# 2         Steven Adams
# 3         Steven Adams
# 4         Steven Adams
#               ...
# 148648     Ivica Zubac
# 148649     Ivica Zubac
# 148650     Ivica Zubac
# 148651     Ivica Zubac
# 148652     Ivica Zubac
# Name: full_name, Length: 148653, dtype: object

# %%
#save the result CSV file here
NBA_df.to_csv("result.csv", index=False, header=True)

# %%
NBA_df.shape
# Out:
# (148653, 28)

# %%
veterans_names = NBA_df[NBA_df['SEASON_ID']== 22005]['full_name'].unique()
veterans_names
# Out:
# array(['Carmelo Anthony', 'Trevor Ariza', 'Vince Carter',
#        'Tyson Chandler', 'Gerald Green', 'Udonis Haslem', 'Dwight Howard',
#        'Andre Iguodala', 'LeBron James', 'Kyle Korver', 'CJ Miles',
#        'Nene', 'Chris Paul', 'Lou Williams', 'Marvin Williams'],
#       dtype=object)

# %%
veterans_starting_season = result.loc[result['full_name'].isin(veterans_names)]

# %%
younger_players = result[result['SEASON_ID']== 22012]['full_name'].unique()

younger_players = [player for player in younger_players if player not in veterans_names]

younger_players
# Out:
# ['LaMarcus Aldridge',
#  'Al-Farouq Aminu',
#  'Ryan Anderson',
#  'D.J. Augustin',
#  'J.J. Barea',
#  'Harrison Barnes',
#  'Will Barton',
#  'Nicolas Batum',
#  'Aron Baynes',
#  'Kent Bazemore',
#  'Bradley Beal',
#  'Marco Belinelli',
#  'Patrick Beverley',
#  'Bismack Biyombo',
#  'Eric Bledsoe',
#  'Avery Bradley',
#  'Alec Burks',
#  'Jimmy Butler',
#  'DeMarre Carroll',
#  'Wilson Chandler',
#  'Mike Conley',
#  'DeMarcus Cousins',
#  'Jae Crowder',
#  'Stephen Curry',
#  'Anthony Davis',
#  'Ed Davis',
#  'DeMar DeRozan',
#  'Goran Dragic',
#  'Andre Drummond',
#  'Jared Dudley',
#  'Kevin Durant',
#  'Wayne Ellington',
#  'Derrick Favors',
#  'Evan Fournier',
#  'Danilo Gallinari',
#  'Marc Gasol',
#  'Rudy Gay',
#  'Paul George',
#  'Taj Gibson',
#  'Eric Gordon',
#  'Danny Green',
#  'Draymond Green',
#  'Jeff Green',
#  'Blake Griffin',
#  'James Harden',
#  'Maurice Harkless',
#  'Tobias Harris',
#  'Gordon Hayward',
#  'John Henson',
#  'George Hill',
# ...

# %%
starting_younger = NBA_df.loc[NBA_df['full_name'].isin(younger_players)]

starting_younger
# Out:
#         SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  \
# 741         22019     200746  21900965  MAR 10, 2020  SAS vs. DAL  W   37
# 742         22019     200746  21900846  FEB 23, 2020    SAS @ OKC  L   21
# 743         22019     200746  21900832  FEB 21, 2020    SAS @ UTA  W   35
# 744         22019     200746  21900805  FEB 11, 2020    SAS @ OKC  W   39
# 745         22019     200746  21900799  FEB 10, 2020    SAS @ DEN  L   35
# ...           ...        ...       ...           ...          ... ..  ...
# 147771      22007     201152  20700120  NOV 16, 2007  PHI vs. POR  W   16
# 147772      22007     201152  20700111  NOV 14, 2007    PHI @ NOH  L    1
# 147773      22007     201152  20700100  NOV 13, 2007    PHI @ DAL  L    3
# 147774      22007     201152  20700088  NOV 11, 2007  PHI vs. NOH  L    4
# 147775      22007     201152  20700055  NOV 07, 2007  PHI vs. CHA  W   11
#
#         FGM  FGA  FG_PCT  ...   REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# ...

# %%
starting_younger['SEASON_ID'] = starting_younger['SEASON_ID'].astype(int)
# Out:
# C:\Users\vera005\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
starting_younger = starting_younger.loc[starting_younger['SEASON_ID'] >= 22012]

starting_younger['SEASON_ID'].unique()
# Out:
# array([22019, 22018, 22017, 22016, 22015, 22014, 22013, 22012],
#       dtype=int64)

# %%
veterans_starting_season['SEASON_ID'] = veterans_starting_season['SEASON_ID'].astype(int)

# %%
veterans_starting_season = veterans_starting_season.loc[veterans_starting_season['SEASON_ID'] >= 22005]

# %%
veterans_starting_season
# Out:
#         SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  \
# 4578        22019       2546  21900966  MAR 10, 2020  POR vs. PHX  W   32
# 4579        22019       2546  21900945  MAR 07, 2020  POR vs. SAC  L   23
# 4580        22019       2546  21900938  MAR 06, 2020    POR @ PHX  L   34
# 4581        22019       2546  21900925  MAR 04, 2020  POR vs. WAS  W   32
# 4582        22019       2546  21900904  MAR 02, 2020    POR @ ORL  W   26
# ...           ...        ...       ...           ...          ... ..  ...
# 146004      22005     101107  20500068  NOV 10, 2005  ATL vs. LAC  L   29
# 146005      22005     101107  20500051  NOV 08, 2005  ATL vs. LAL  L   27
# 146006      22005     101107  20500041  NOV 05, 2005    ATL @ POR  L   25
# 146007      22005     101107  20500028  NOV 04, 2005    ATL @ LAC  L   35
# 146008      22005     101107  20500017  NOV 02, 2005    ATL @ GSW  L   26
#
#         FGM  FGA  FG_PCT  ...  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE  \
# ...

# %%
veterans_starting_season['FG3M'] = veterans_starting_season['FG3M'].astype(float)

# %%
starting_younger['FG3M'] = starting_younger['FG3M'].astype(float)

# %%
starting_younger['FGM'] = starting_younger['FGM'].astype(float)

# %%
starting_younger['FG3A'] = starting_younger['FG3A'].astype(float)

# %%
veterans_starting_season['FGM'] = veterans_starting_season['FGM'].astype(float)

# %%
veterans_starting_season['FG3A'] = veterans_starting_season['FG3A'].astype(float)

# %%
veterans_starting_season['3_point_made_ratio'] = veterans_starting_season['FG3M'] / veterans_starting_season['FGM']

# %%
starting_younger['3_point_made_ratio'] = starting_younger['FG3M'] / starting_younger['FGM']

# %%
veterans_starting_season.columns
# Out:
# Index(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
#        'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE', 'full_name',
#        '3_point_made_ratio', '2_point_made_ratio', '3_point_attempt_average'],
#       dtype='object')

# %%
veterans_starting_season['3_point_made_ratio'].unique()
# Out:
# array([0.22222222, 0.5       , 0.33333333, 0.375     , 0.        ,
#        0.2       , 0.4       , 0.45454545,        nan, 0.28571429,
#        0.125     , 0.14285714, 0.42857143, 0.27272727, 0.11111111,
#        1.        , 0.25      , 0.6       , 0.66666667, 0.75      ,
#        0.55555556, 0.85714286, 0.71428571, 0.16666667, 0.875     ,
#        0.57142857, 0.3       , 0.09090909, 0.1       , 0.13333333,
#        0.54545455, 0.46153846, 0.23076923, 0.18181818, 0.53846154,
#        0.21428571, 0.44444444, 0.15384615, 0.08333333, 0.36363636,
#        0.0625    , 0.41666667, 0.30769231, 0.38461538, 0.26086957,
#        0.07692308, 0.11764706, 0.17647059, 0.05882353, 0.38888889,
#        0.35714286, 0.29411765, 0.07142857, 0.06666667, 0.15789474,
#        0.8       , 0.83333333, 0.625     , 0.77777778, 0.72727273,
#        0.90909091, 0.31578947, 0.4375    , 0.26666667, 0.64285714,
#        0.63636364, 0.88888889, 0.23529412, 0.1875    , 0.3125    ,
# ...

# %%
veterans_starting_season['2_point_made_ratio'] = 1.00 - (veterans_starting_season['FG3M'] / veterans_starting_season['FGM'])

# %%
starting_younger['2_point_made_ratio'] = 1.00 - (starting_younger['FG3M'] / starting_younger['FGM'])

# %%
veterans_starting_season['2_point_made_ratio'].unique()
# Out:
# array([0.77777778, 0.5       , 0.66666667, 0.625     , 1.        ,
#        0.8       , 0.6       , 0.54545455,        nan, 0.71428571,
#        0.875     , 0.85714286, 0.57142857, 0.72727273, 0.88888889,
#        0.        , 0.75      , 0.4       , 0.33333333, 0.25      ,
#        0.44444444, 0.14285714, 0.28571429, 0.83333333, 0.125     ,
#        0.42857143, 0.7       , 0.90909091, 0.9       , 0.86666667,
#        0.45454545, 0.53846154, 0.76923077, 0.81818182, 0.46153846,
#        0.78571429, 0.55555556, 0.84615385, 0.91666667, 0.63636364,
#        0.9375    , 0.58333333, 0.69230769, 0.61538462, 0.73913043,
#        0.92307692, 0.88235294, 0.82352941, 0.94117647, 0.61111111,
#        0.64285714, 0.70588235, 0.92857143, 0.93333333, 0.84210526,
#        0.2       , 0.16666667, 0.375     , 0.22222222, 0.27272727,
#        0.09090909, 0.68421053, 0.5625    , 0.73333333, 0.35714286,
#        0.36363636, 0.11111111, 0.76470588, 0.8125    , 0.6875    ,
# ...

# %%
#Veterans 3 and 2 point ratio average using the mean function.
veterans_starting_season.groupby('SEASON_ID')[['3_point_made_ratio','2_point_made_ratio','MIN']].mean()
# Out:
#            3_point_made_ratio  2_point_made_ratio        MIN
# SEASON_ID
# 22005                0.121943            0.878057  30.652542
# 22006                0.114420            0.885580  31.228544
# 22007                0.126349            0.873651  31.710041
# 22008                0.149384            0.850616  31.431628
# 22009                0.155279            0.844721  32.127572
# 22010                0.180859            0.819141  30.953582
# 22011                0.197330            0.802670  29.885954
# 22012                0.252872            0.747128  29.002944
# 22013                0.285090            0.714910  30.150202
# 22014                0.321198            0.678802  27.784200
# 22015                0.297929            0.702071  27.642157
# 22016                0.340779            0.659221  27.317492
# 22017                0.365314            0.634686  26.761955
# 22018                0.419976            0.580024  23.615288
# ...

# %%
#veterans minutes appear to be decreasing around 2018.
veterans_starting_season.groupby('SEASON_ID')['MIN'].sum()
# Out:
# SEASON_ID
# 22005    28936
# 22006    32384
# 22007    30949
# 22008    33789
# 22009    31228
# 22010    30675
# 22011    24895
# 22012    29554
# 22013    29909
# 22014    28840
# 22015    28195
# 22016    27017
# 22017    25183
# 22018    18845
# 22019    13537
# Name: MIN, dtype: int64

# %%
#the season id needed to be changed to string in order to be plotted
veterans_starting_season['SEASON_ID'] = veterans_starting_season['SEASON_ID'].astype(str)

# %%
#created a new variable to plot the veterans 2 and 3 pt data
vet_plot = veterans_starting_season.groupby('SEASON_ID')[['3_point_made_ratio','2_point_made_ratio']].mean()



# veterans_starting_season['FG3A'] = veterans_starting_season['FG3A'].astype(float)

# %%
vet_plot['3_point_made_ratio'].max()
# Out:
# 0.4199759754415626

# %%
#line graph for both displayed here. 
plt.plot(vet_plot)
plt.title('Veterans 3 vs. 2 Made Ratio')
plt.xticks(rotation=90)
plt.legend(['3 pt ratio','2 pt ratio'])

plt.xlabel('years')
plt.ylabel('3pt ratio')

plt.show()

# %%
#converting the season to a string function here again.

starting_younger['SEASON_ID'] = starting_younger['SEASON_ID'].astype(str)

# %%
#creating a variable for the young players here to plot. 
starting_younger.groupby('SEASON_ID')[['3_point_made_ratio','2_point_made_ratio','MIN']].mean()
# Out:
#            3_point_made_ratio  2_point_made_ratio        MIN
# SEASON_ID
# 22012                0.198081            0.801919  26.576119
# 22013                0.216223            0.783777  28.246341
# 22014                0.226470            0.773530  27.896152
# 22015                0.246065            0.753935  28.943449
# 22016                0.267516            0.732484  28.793755
# 22017                0.283964            0.716036  28.094618
# 22018                0.321311            0.678689  27.379374
# 22019                0.339247            0.660753  25.583402

# %%
starting_younger.groupby('SEASON_ID')['MIN'].sum()
# Out:
# SEASON_ID
# 22012    195866
# 22013    208458
# 22014    202275
# 22015    216497
# 22016    214859
# 22017    198348
# 22018    193271
# 22019    124847
# Name: MIN, dtype: int64

# %%
starting_younger.groupby('SEASON_ID')['MIN'].mean()
# Out:
# SEASON_ID
# 22012    26.576119
# 22013    28.246341
# 22014    27.896152
# 22015    28.943449
# 22016    28.793755
# 22017    28.094618
# 22018    27.379374
# 22019    25.583402
# Name: MIN, dtype: float64

# %%
young_plot= starting_younger.groupby('SEASON_ID')[['3_point_made_ratio','2_point_made_ratio','MIN']].mean()
young_plot
# Out:
#            3_point_made_ratio  2_point_made_ratio        MIN
# SEASON_ID
# 22012                0.198081            0.801919  26.576119
# 22013                0.216223            0.783777  28.246341
# 22014                0.226470            0.773530  27.896152
# 22015                0.246065            0.753935  28.943449
# 22016                0.267516            0.732484  28.793755
# 22017                0.283964            0.716036  28.094618
# 22018                0.321311            0.678689  27.379374
# 22019                0.339247            0.660753  25.583402

# %%
young_plot['3_point_made_ratio'].max()
# Out:
# 0.33924704744981227

# %%
#plotting the young players 2 and 3 pt lines
plt.plot(young_plot)
plt.title('Younger Players 3 vs. 2 Made Ratio')
plt.xticks(rotation=90)
plt.legend(['3 pt ratio','2 pt ratio'])
plt.xlabel('years')
plt.ylabel('3pt ratio')

plt.show()

# %%
#merging both young and veteran dataframes to plot both 3 pt data in one line
young_veterans_df = pd.merge(vet_plot, young_plot, how='inner', on = ["SEASON_ID"])

young_veterans_df.head(10)
# Out:
#            3_point_made_ratio_x  2_point_made_ratio_x  3_point_made_ratio_y  \
# SEASON_ID
# 22012                  0.252872              0.747128              0.198081
# 22013                  0.285090              0.714910              0.216223
# 22014                  0.321198              0.678802              0.226470
# 22015                  0.297929              0.702071              0.246065
# 22016                  0.340779              0.659221              0.267516
# 22017                  0.365314              0.634686              0.283964
# 22018                  0.419976              0.580024              0.321311
# 22019                  0.344381              0.655619              0.339247
#
#            2_point_made_ratio_y
# SEASON_ID
# 22012                  0.801919
# 22013                  0.783777
# 22014                  0.773530
# 22015                  0.753935
# 22016                  0.732484
# 22017                  0.716036
# ...

# %%
#created a line graph with both the young and veteran players 3 point ratio
young_veterans_line = young_veterans_df[['3_point_made_ratio_x', '3_point_made_ratio_y']]

plt.plot(young_veterans_line)
plt.xticks(rotation=90)
plt.title('Veterans and Younger Players 3 Made Ratio')
plt.legend(['Veterans','Younger Players'])
plt.xlabel('Seasons Played')
plt.ylabel('Young and Veteran Player Ratio')
plt.show()

# %%
#there appears to be a significant drop around the 2018 season where veterans are shooting less 3s, but this looks to
#be directly related to their minutes being reduced and giving more time to the younger players of the franchise.

# %%
younger_FG3A = starting_younger.groupby('SEASON_ID', as_index = False)['FG3A'].mean()

FG3A_zip = zip(younger_FG3A['SEASON_ID'], younger_FG3A['FG3A'])

three_attempt = {}
for i in FG3A_zip:
    three_attempt[i[0]] = i[1]

# %%
younger_FG3A
# Out:
#   SEASON_ID      FG3A
# 0     22012  2.259430
# 1     22013  2.737805
# 2     22014  2.834092
# 3     22015  3.275134
# 4     22016  3.681721
# 5     22017  3.710623
# 6     22018  4.061340
# 7     22019  3.848975

# %%
younger_FG3ASUM = starting_younger.groupby('SEASON_ID', as_index = False)['FG3A'].sum()

FG3A_sip = zip(younger_FG3A['SEASON_ID'], younger_FG3A['FG3A'])

three_attempt = {}
for i in FG3A_sip:
    three_attempt[i[0]] = i[1]

# %%
younger_FG3ASUM
# Out:
#   SEASON_ID     FG3A
# 0     22012  16652.0
# 1     22013  20205.0
# 2     22014  20550.0
# 3     22015  24498.0
# 4     22016  27473.0
# 5     22017  26197.0
# 6     22018  28669.0
# 7     22019  18783.0

# %%
veteran_FG3A = veterans_starting_season.groupby('SEASON_ID', as_index = False)['FG3A'].mean()

veteran_FG3A_zip = zip(veteran_FG3A['SEASON_ID'], veteran_FG3A['FG3A'])

veteran_attempt = {}
for i in veteran_FG3A_zip:
    veteran_attempt[i[0]] = i[1]

# %%
veteran_FG3SUM = veterans_starting_season.groupby('SEASON_ID', as_index = False)['FG3A'].sum()

veteran_FG3A_sip = zip(veteran_FG3A['SEASON_ID'], veteran_FG3A['FG3A'])

veteran_attempt = {}
for i in veteran_FG3A_sip:
    veteran_attempt[i[0]] = i[1]

# %%
veteran_FG3SUM
# Out:
#    SEASON_ID    FG3A
# 0      22005  1783.0
# 1      22006  1888.0
# 2      22007  1951.0
# 3      22008  2448.0
# 4      22009  2409.0
# 5      22010  2489.0
# 6      22011  1972.0
# 7      22012  3094.0
# 8      22013  3512.0
# 9      22014  3877.0
# 10     22015  3504.0
# 11     22016  3786.0
# 12     22017  3971.0
# 13     22018  3321.0
# 14     22019  1975.0

# %%
veteran_FG3A
# Out:
#    SEASON_ID      FG3A
# 0      22005  1.888771
# 1      22006  1.820636
# 2      22007  1.998975
# 3      22008  2.277209
# 4      22009  2.478395
# 5      22010  2.511604
# 6      22011  2.367347
# 7      22012  3.036310
# 8      22013  3.540323
# 9      22014  3.735067
# 10     22015  3.435294
# 11     22016  3.828109
# 12     22017  4.219979
# 13     22018  4.161654
# 14     22019  3.507993

# %%
plt.plot(veteran_FG3A['SEASON_ID'], veteran_FG3A['FG3A'])
plt.xticks(rotation=90)
plt.legend(['3pt Attempts'])
plt.xlabel('Seasons')
plt.ylabel('3pt Attempt Percentage')
plt.show()

# %%
plt.plot(younger_FG3A['SEASON_ID'], younger_FG3A['FG3A'])
plt.xticks(rotation=90)
plt.legend(['3pt Attempts'])
plt.xlabel('Seasons')
plt.ylabel('3pt Attempt Percentage')
plt.show()

# %%
young_veterans_attempts = pd.merge(veteran_FG3A, younger_FG3A, how='inner', on = ["SEASON_ID"])

young_veterans_attempts
# Out:
#   SEASON_ID    FG3A_x    FG3A_y
# 0     22012  3.036310  2.259430
# 1     22013  3.540323  2.737805
# 2     22014  3.735067  2.834092
# 3     22015  3.435294  3.275134
# 4     22016  3.828109  3.681721
# 5     22017  4.219979  3.710623
# 6     22018  4.161654  4.061340
# 7     22019  3.507993  3.848975

# %%
plt.plot(young_veterans_attempts['SEASON_ID'], young_veterans_attempts[['FG3A_x', 'FG3A_y']])
plt.legend(['Veterans','Younger Players'])

plt.xticks(rotation=90)
plt.title('Veterans and Younger Players 3pt Attempt Average')
plt.xlabel('Seasons Played')
plt.ylabel('Young and Veteran Attempt')
plt.show()

#veterans have adjusted thier game throughout the years to include 3pt shooting. this adds longevity to their game and makes
#their skill set valuable.

# %%
young_veterans_attempts[['SEASON_ID','FG3A_x','FG3A_y']].plot(kind = 'bar', x ='SEASON_ID', y =['FG3A_x','FG3A_y'], figsize=[9,5])

# plt.plot(young_veterans_attempts['SEASON_ID'], young_veterans_attempts[['FG3A_x', 'FG3A_y']])
# plt.xticks(rotation=90)
plt.legend(['Veterans','Youngins'])
plt.show()

# %%
veterans_starting_season['3_point_attempt_average'] = veterans_starting_season['SEASON_ID'].map(veteran_attempt)

veterans_starting_season['3_point_attempt_average']
# Out:
# 4578      3.507993
# 4579      3.507993
# 4580      3.507993
# 4581      3.507993
# 4582      3.507993
#             ...
# 146004    1.888771
# 146005    1.888771
# 146006    1.888771
# 146007    1.888771
# 146008    1.888771
# Name: 3_point_attempt_average, Length: 14188, dtype: float64

# %%
#veterans shoot on average, 5 three pointers per game
veterans_starting_season['3_point_attempt_average'].max()
# Out:
# 4.219978746014878

# %%
starting_younger['3_point_attempt_average'] = starting_younger['SEASON_ID'].map(three_attempt)

starting_younger['3_point_attempt_average']
# Out:
# 741       3.848975
# 742       3.848975
# 743       3.848975
# 744       3.848975
# 745       3.848975
#             ...
# 147410    2.259430
# 147411    2.259430
# 147412    2.259430
# 147413    2.259430
# 147414    2.259430
# Name: 3_point_attempt_average, Length: 55942, dtype: float64

# %%
starting_younger['3_point_attempt_average'].max()
# Out:
# 4.061340133163338
